# %%
import numpy as np

base_path = "./processed-data/"

currents = np.load(base_path + 'currents.npz', allow_pickle=True)['currents']
timestamps = np.load(base_path + 'timestamps.npz', allow_pickle=True)['timestamps']
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/_npyio_impl.py:493, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     492 try:
# --> 493     return pickle.load(fid, **pickle_kwargs)
#     494 except Exception as e:
#
# UnpicklingError: invalid load key, 'v'.
#
# The above exception was the direct cause of the following exception:
#
# UnpicklingError                           Traceback (most recent call last)
# Cell In[37], line 5
#       1 import numpy as np
#       3 base_path = "./processed-data/"
# ----> 5 currents = np.load(base_path + 'currents.npz', allow_pickle=True)['currents']
#       6 timestamps = np.load(base_path + 'timestamps.npz', allow_pickle=True)['timestamps']
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/_npyio_impl.py:495, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     493     return pickle.load(fid, **pickle_kwargs)
#     494 except Exception as e:
# --> 495     raise pickle.UnpicklingError(
#     496         f"Failed to interpret file {file!r} as a pickle") from e
#
# UnpicklingError: Failed to interpret file './processed-data/currents.npz' as a pickle

# %%
currents.shape
# Out:
# (17535, 2, 74, 93)

# %%
timestamps[0]
# Out:
# datetime.datetime(2023, 1, 1, 0, 0)

# %%
from datetime import datetime, timedelta
import numpy as np

# MATLAB datenum → Python datetime
def matlab_datenum_to_datetime(datenum_array):
    """
    Convert MATLAB datenum (float days since year 0) to Python datetime.
    """
    return np.array([
        datetime.fromordinal(int(d)) + timedelta(days=float(d) % 1) - timedelta(days=366)
        for d in datenum_array
    ])

# %%
timestamps = matlab_datenum_to_datetime(timestamps)

# %%
timestamps.shape
# Out:
# (17535,)

# %%
import os

np.savez_compressed(os.path.join("./processed-data/", 'timestamps.npz'), timestamps=timestamps)
